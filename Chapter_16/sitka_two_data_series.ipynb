# %%
import pandas as pd
from datetime import datetime
import matplotlib.pyplot as plt

# %% [markdown]
# # Import Sitka yearly temperature data

# %%
data = pd.read_csv('/Users/joseservin/Project_Data_Visualization/Chapter_16/sitka_weather_2014.csv')
data
# Out:
#            AKST  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0      2014-1-1                46                 42                37
# 1      2014-1-2                41                 38                35
# 2      2014-1-3                39                 36                34
# 3      2014-1-4                43                 38                34
# 4      2014-1-5                44                 42                41
# ..          ...               ...                ...               ...
# 351  2014-12-18                45                 43                41
# 352  2014-12-19                46                 44                42
# 353  2014-12-20                46                 44                41
# 354  2014-12-21                42                 40                37
# 355  2014-12-22                45                 42                39
#
#      Max Dew PointF  MeanDew PointF  Min DewpointF  Max Humidity  \
# ...

# %% [markdown]
# # Find average max temperature grouped by month

# %%
data.insert(1, 'Month', pd.DatetimeIndex(data['AKST']).month)

# %%
data
# Out:
#            AKST  Month  Max TemperatureF  Mean TemperatureF  Min TemperatureF  \
# 0      2014-1-1      1                46                 42                37
# 1      2014-1-2      1                41                 38                35
# 2      2014-1-3      1                39                 36                34
# 3      2014-1-4      1                43                 38                34
# 4      2014-1-5      1                44                 42                41
# ..          ...    ...               ...                ...               ...
# 351  2014-12-18     12                45                 43                41
# 352  2014-12-19     12                46                 44                42
# 353  2014-12-20     12                46                 44                41
# 354  2014-12-21     12                42                 40                37
# 355  2014-12-22     12                45                 42                39
#
# ...

# %%
month_data = data.groupby(['Month']).mean()

# %%
month_data
# Out:
#        Max TemperatureF  Mean TemperatureF  Min TemperatureF  Max Dew PointF  \
# Month
# 1             45.709677          41.903226         38.032258       40.451613
# 2             37.107143          32.142857         27.000000       25.678571
# 3             42.516129          37.290323         32.612903       29.483871
# 4             47.700000          42.700000         38.133333       38.633333
# 5             56.806452          51.290323         46.129032       44.774194
# 6             57.400000          52.366667         48.266667       49.033333
# 7             61.161290          56.870968         53.161290       54.548387
# 8             62.677419          57.741935         53.387097       56.193548
# 9             59.033333          54.600000         50.466667       53.833333
# 10            50.870968          46.290323         41.935484       45.322581
# 11            43.366667          39.033333         34.500000       38.166667
# ...

# %% [markdown]
# # Find month with highest and lowest max temp

# %%
month_data['Max TemperatureF'].idxmax()
# Out:
# 8

# %%
month_data['Max TemperatureF'].idxmin()
# Out:
# 2

# %% [markdown]
# # Create February data DF

# %%
data['AKST'] = pd.to_datetime(data['AKST'])

# %%
feb_data = data.loc[data['Month'] == 2]

# %%
len(feb_data.index) # 28 days in Feb
# Out:
# 28

# %%
feb_data.dtypes
# Out:
# AKST                          datetime64[ns]
# Month                                  int64
# Max TemperatureF                       int64
# Mean TemperatureF                      int64
# Min TemperatureF                       int64
# Max Dew PointF                         int64
# MeanDew PointF                         int64
# Min DewpointF                          int64
# Max Humidity                           int64
#  Mean Humidity                         int64
#  Min Humidity                          int64
#  Max Sea Level PressureIn            float64
#  Mean Sea Level PressureIn           float64
#  Min Sea Level PressureIn            float64
#  Max VisibilityMiles                   int64
#  Mean VisibilityMiles                  int64
#  Min VisibilityMiles                   int64
#  Max Wind SpeedMPH                     int64
#  Mean Wind SpeedMPH                    int64
#  Max Gust SpeedMPH                   float64
# PrecipitationIn                      float64
# ...

# %%
x_axis = feb_data['AKST']

# %%
y_axis = feb_data['Max TemperatureF']

# %%
y_axis2 = feb_data['Min TemperatureF']

# %%
plt.plot(x_axis, y_axis, c='red')
plt.plot(x_axis, y_axis2, c='blue')
plt.xticks(x_axis, rotation='vertical')
plt.fill_between(x_axis, y_axis, y_axis2, facecolor = 'blue', alpha = 0.1)
plt.show()
